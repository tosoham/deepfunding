# %%
import polars as pl
import os

# %%
df_pl_ground = pl.read_csv(os.path.join("dataset_Oct_9_2025", "private_leaderboard_groundtruth.csv"))
df_pl = pl.read_csv(os.path.join("dataset_Oct_9_2025", "private_leaderboard.csv"))
df_rp = pl.read_csv(os.path.join("dataset_Oct_9_2025", "raw_private.csv"))
df_ss = pl.read_csv(os.path.join("dataset_Oct_9_2025", "sample_submission.csv"))
df_test = pl.read_csv(os.path.join("dataset_Oct_9_2025", "test.csv"))
df_train = pl.read_csv(os.path.join("dataset_Oct_9_2025", "train.csv"))

# %%
df_pl_ground.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬──────────┬───────────┐
# │ SOURCE_A                        ┆ SOURCE_B                        ┆ TARGET   ┆ B_OVER_A  │
# │ ---                             ┆ ---                             ┆ ---      ┆ ---       │
# │ str                             ┆ str                             ┆ str      ┆ f64       │
# ╞═════════════════════════════════╪═════════════════════════════════╪══════════╪═══════════╡
# │ https://github.com/prysmaticla… ┆ https://github.com/status-im/n… ┆ ethereum ┆ -1.286474 │
# │ https://github.com/ethereum/re… ┆ https://github.com/paradigmxyz… ┆ ethereum ┆ -0.693147 │
# │ https://github.com/safe-global… ┆ https://github.com/ethereum/we… ┆ ethereum ┆ 2.995732  │
# │ https://github.com/paradigmxyz… ┆ https://github.com/ethereum/go… ┆ ethereum ┆ 5.164786  │
# │ https://github.com/chainsafe/l… ┆ https://github.com/eth-infinit… ┆ ethereum ┆ -2.079442 │
# ...

# %%
df_pl.head()
# Out:
# shape: (5, 5)
# ┌─────────────────────────┬──────────┬─────────────────────────┬────────────────────────┬──────────┐
# │ timestamp               ┆ juror    ┆ repo_a                  ┆ repo_b                 ┆ parent   │
# │ ---                     ┆ ---      ┆ ---                     ┆ ---                    ┆ ---      │
# │ str                     ┆ str      ┆ str                     ┆ str                    ┆ str      │
# ╞═════════════════════════╪══════════╪═════════════════════════╪════════════════════════╪══════════╡
# │ 2024-12-24T18:03:10.396 ┆ L1Juror1 ┆ https://github.com/prys ┆ https://github.com/sta ┆ ethereum │
# │ Z                       ┆          ┆ maticla…                ┆ tus-im/n…              ┆          │
# │ 2024-12-24T18:20:59.999 ┆ L1Juror1 ┆ https://github.com/ethe ┆ https://github.com/par ┆ ethereum │
# │ Z                       ┆          ┆ reum/re…                ┆ adigmxyz…              ┆          │
# ...

# %%
df_rp.head()
# Out:
# shape: (5, 8)
# ┌─────────────┬──────────┬─────────────┬─────────────┬──────────┬────────┬────────────┬────────────┐
# │ timestamp   ┆ juror    ┆ repo_a      ┆ repo_b      ┆ parent   ┆ choice ┆ multiplier ┆ reasoning  │
# │ ---         ┆ ---      ┆ ---         ┆ ---         ┆ ---      ┆ ---    ┆ ---        ┆ ---        │
# │ str         ┆ str      ┆ str         ┆ str         ┆ str      ┆ i64    ┆ f64        ┆ str        │
# ╞═════════════╪══════════╪═════════════╪═════════════╪══════════╪════════╪════════════╪════════════╡
# │ 2024-12-24T ┆ L1Juror1 ┆ https://git ┆ https://git ┆ ethereum ┆ 1      ┆ 3.62       ┆ According  │
# │ 18:03:10.39 ┆          ┆ hub.com/pry ┆ hub.com/sta ┆          ┆        ┆            ┆ to https:/ │
# │ 6Z          ┆          ┆ smaticla…   ┆ tus-im/n…   ┆          ┆        ┆            ┆ /clientdiv │
# │             ┆          ┆             ┆             ┆          ┆        ┆            ┆ …          │
# ...

# %%
df_ss.head()
# Out:
# shape: (5, 3)
# ┌─────────────────────────────────┬──────────┬──────────┐
# │ repo                            ┆ parent   ┆ weight   │
# │ ---                             ┆ ---      ┆ ---      │
# │ str                             ┆ str      ┆ f64      │
# ╞═════════════════════════════════╪══════════╪══════════╡
# │ https://github.com/a16z/helios  ┆ ethereum ┆ 0.011847 │
# │ https://github.com/alloy-rs/al… ┆ ethereum ┆ 0.037177 │
# │ https://github.com/apeworx/ape  ┆ ethereum ┆ 0.037247 │
# │ https://github.com/chainsafe/l… ┆ ethereum ┆ 0.039195 │
# │ https://github.com/consensys/t… ┆ ethereum ┆ 0.007649 │
# └─────────────────────────────────┴──────────┴──────────┘

# %%
df_test.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────────┬──────────┐
# │ repo                            ┆ parent   │
# │ ---                             ┆ ---      │
# │ str                             ┆ str      │
# ╞═════════════════════════════════╪══════════╡
# │ https://github.com/a16z/helios  ┆ ethereum │
# │ https://github.com/alloy-rs/al… ┆ ethereum │
# │ https://github.com/apeworx/ape  ┆ ethereum │
# │ https://github.com/chainsafe/l… ┆ ethereum │
# │ https://github.com/consensys/t… ┆ ethereum │
# └─────────────────────────────────┴──────────┘

# %%
df_train.head()
# Out:
# shape: (5, 8)
# ┌─────────────┬──────────┬─────────────┬─────────────┬──────────┬────────┬────────────┬────────────┐
# │ timestamp   ┆ juror    ┆ repo_a      ┆ repo_b      ┆ parent   ┆ choice ┆ multiplier ┆ reasoning  │
# │ ---         ┆ ---      ┆ ---         ┆ ---         ┆ ---      ┆ ---    ┆ ---        ┆ ---        │
# │ str         ┆ str      ┆ str         ┆ str         ┆ str      ┆ i64    ┆ f64        ┆ str        │
# ╞═════════════╪══════════╪═════════════╪═════════════╪══════════╪════════╪════════════╪════════════╡
# │ 2024-12-24T ┆ L1Juror1 ┆ https://git ┆ https://git ┆ ethereum ┆ 2      ┆ 10.0       ┆ As a first │
# │ 17:55:51.91 ┆          ┆ hub.com/vyp ┆ hub.com/web ┆          ┆        ┆            ┆ approximat │
# │ 9Z          ┆          ┆ erlang/v…   ┆ 3/web3.j…   ┆          ┆        ┆            ┆ ion, supp… │
# │ 2024-12-24T ┆ L1Juror1 ┆ https://git ┆ https://git ┆ ethereum ┆ 1      ┆ 6.0        ┆ Lighthouse │
# ...

# %%
df_train.shape
# Out:
# (407, 8)

# %%
df_test.shape
# Out:
# (45, 2)
